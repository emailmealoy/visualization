# %% [markdown]
# The second version of the assignment is a google sheet document which can be accessed with the following link.
#
# https://docs.google.com/spreadsheets/d/e/2PACX-1vQ83S8ppN1OSlnDE9wCFAy9QrHbakJ3TH7yuOTM_E2LgUm1OVqqJYr20l6fIH1xDy7YLjP63B5maOSK/pubhtml
